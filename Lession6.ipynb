# %% [markdown]
# <a href="https://colab.research.google.com/github/HannaSuh0/colab/blob/main/Lession6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 구구단

# %%
j = 0
j = 0

for i in range(2, 10) :
  for j in range(1, 10) :
    print(i, "X", j, "=", i * j)
  print("")
# Out:
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
#
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
#
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
#
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
#
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
#
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
#
# 8 X 1 = 8
# 8 X 2 = 16
# 8 X 3 = 24
# 8 X 4 = 32
# 8 X 5 = 40
# 8 X 6 = 48
# 8 X 7 = 56
# 8 X 8 = 64
# 8 X 9 = 72
#
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81

# %% [markdown]
# for문과 while문의 비교

# %%
i=0
while (i<5) :
  print("즐거운 난생 처음 ^^")
  i = 1+1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# 즐거운 난생 처음 ^^
# ...

# %% [markdown]
# while문의 무한 반복

# %%
hap = 0
num1, num2 = 0,0

while True :
  num1 = int(input("숫자1 ==> "))
  num2 = int(input("숫자2 ==> "))
  
  hap = num1 + num2 
  print(num1, "+", num2, "=", hap)
# Out:
# 숫자1 ==> 5
# 숫자2 ==> 2
# 5 + 2 = 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e1345939b5f2> in <module>
#       3
#       4 while True :
# ----> 5   num1 = int(input("숫자1 ==> "))
#       6   num2 = int(input("숫자2 ==> "))
#       7
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
# ...

# %%
from warnings import resetwarnings
while True :
  num1 = input("숫자1 입력 => ")
  if num1 == "0" : break
  num2 = input("숫자2 입력 => ")
  rasult = float(num1) + float(num2)
  print(num1, "+", num2, "=", rasult)
# Out:
# 숫자1 입력 => 1
# 숫자2 입력 => 2
# 1 + 2 = 3.0
# 숫자1 입력 => 3
# 숫자2 입력 => 4
# 3 + 4 = 7.0
# 숫자1 입력 => 5
# 숫자2 입력 => 9
# 5 + 9 = 14.0
# 숫자1 입력 => 454444444444444444444444444444444444444
# 숫자2 입력 => 5555555555555555555555555555555555555555555
# 454444444444444444444444444444444444444 + 5555555555555555555555555555555555555555555 = 5.55601e+42
# 숫자1 입력 => 666666666666666666666666666666666666666
# 숫자2 입력 => 898989569568956
# 666666666666666666666666666666666666666 + 898989569568956 = 6.6666666666666665e+38
# 숫자1 입력 => 598748568654
# 숫자2 입력 => 5886465486451256
# 598748568654 + 5886465486451256 = 5887064235019910.0
# 숫자1 입력 => 11010110101
# 숫자2 입력 => 03030330
# 11010110101 + 03030330 = 11013140431.0
# 숫자1 입력 => 00000000
# 숫자2 입력 => 00000000
# 00000000 + 00000000 = 0.0
# 숫자1 입력 => 끝
# 숫자2 입력 => 끝
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-16e7e773deb4> in <module>
# ...

# %%
hap = 0
num1, num2 = 0,0

while True :
  num1 = int(input("숫자1 => "))
  if num1 == 0 :
    break
  num2 = int(input("숫자2 => "))
  
  hap = num1 + num2
  print(num1, "+", num2, "=", hap)

  print("0을 입력해서 계산을 종료합니다.")
# Out:
# 숫자1 => 888
# 숫자2 => 777
# 888 + 777 = 1665
# 0을 입력해서 계산을 종료합니다.
# 숫자1 => 999
# 숫자2 => 4444
# 999 + 4444 = 5443
# 0을 입력해서 계산을 종료합니다.
# 숫자1 => 0

# %%
import random

count = 0
dice1, dice2, dice3 = 0,0,0

while True :
  count += 1
  dice1 = random.randint(1,6)
  dice2 = random.randint(1,6)
  dice3 = random.randint(1,6)

  if (dice1 == dice2 == dice3) :
    break

print("3개의 주사위는 모두", dice1, "입니다.")
print("같은 숫자가 나오기까지", count, "번 던졌습니다.")
# Out:
# 3개의 주사위는 모두 2 입니다.
# 같은 숫자가 나오기까지 18 번 던졌습니다.

# %%
import random
count = 0
while True :
  r1, r2 = random, randint(1,6), random.randint(1,6)
  r3 = random, randint(1,6)
  count = count + 1
  if r1 == r2 == r3 : break
print("3개의 주사위는 모두", r1, "나왔다.")
print("같은 숫자가 나오기까지", count,"번 던졌습니다.")

# %%
import random

computer, user = 0,0

for i in range(1, 11) :
  computer = random.randint(1, 5)
  print("게임", i, "회:", end='')
  user = int(input("컴퓨터가 생각한 숫자는 ? "))

  if computer == user :
    print("맞혔네요. 축하합니다~! ")
    break
  else :
    print("아까워요 ㅠㅠ", computer, "였는데요. 다시 해보세요~ ")
    continue
  print("게임을 마칩니다.")
# Out:
# 게임 1 회:컴퓨터가 생각한 숫자는 ? 5
# 아까워요 ㅠㅠ 3 였는데요. 다시 해보세요~
# 게임 2 회:컴퓨터가 생각한 숫자는 ? 2
# 아까워요 ㅠㅠ 5 였는데요. 다시 해보세요~
# 게임 3 회:컴퓨터가 생각한 숫자는 ? 2
# 아까워요 ㅠㅠ 5 였는데요. 다시 해보세요~
# 게임 4 회:컴퓨터가 생각한 숫자는 ? 2
# 맞혔네요. 축하합니다~!

# %% [markdown]
# 야구게임

# %%
import random
com_list = [1,2,3,4,5,6,7,8,9]
com_num = []
for i in range(3) :
   r = com_num.append(random.choice(com_list))
print(com_num)
# Out:
# [3, 8, 4]

# %%
import random
com_list = [1,2,3,4,5,6,7,8,9]
com_num, usr_num = [], []

def usr_fun() :
 usr = input("3개의 숫자를 입력(1~9) => ")
for i in range(0,5,2) :
 usr_num.append(int(usr[i]))
# 컴퓨터 3개의 중복되지 않는 숫자 만들기
for i in range(3) :
  r = random.choice(com_list)
  com_list.remove(r)
  com_num.append(r)

print("** 야구게임 ** ")
#스트라이크 및 볼 판정-----------------------------------------------------
strike, ball = 0, 0
while True :
  usr_num.clear()
  usr_fum()
  for i in range(3) :
   if com_num[i] == usr_num[i] :
     strike = strike + 1
   elif usr_num[i] in com_num :
    ball = ball + 1
  print(strike, "스트라이크", " : ", ball, "골")
  if strike == 3 :
    print("축하합니다.")
    break
  strike, ball = 0,0
# Out:
# ** 야구게임 **
# 3개의 숫자를 입력(1~9) => 1 2 3
# [4, 9, 5] [1, 2, 3] 0 0
